# %% [markdown]
# ## Apu Apustaja's favorite holiday

# %% [markdown]
# *The purpose of this Jupyter Notebook is to present the favorite holiday destination of Apu Apustaja.*

# %% [markdown]
# ## Our traveller's name is Apu Apustaja

# %%
name = input("Enter Traveller's Name: ")
# Out:
# Enter Traveller's Name: Apu Apustaja

# %% [markdown]
# ## This is a picture of our traveller, Apu Apustaja

# %%
from IPython.display import Image
Image("https://i.kym-cdn.com/entries/icons/mobile/000/021/523/apu_apustaja_kym.jpg")

# %% [markdown]
# ## This is a picture of our Apu's favourite holiday destination

# %%
from IPython.display import Image
Image("https://img.freepik.com/free-vector/ducks-pond-cartoon-style_1308-96906.jpg")

# %% [markdown]
# ## Three things Apu likes about his favourite holiday destination:
#  - water
#  - ducks
#  - water lilies

# %% [markdown]
# ## This is a video of Apu:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('HFZOEtbnLcI')

# %% [markdown]
# ## What functions I have used:
#
# - I used an iput function to ask about Apu Apustaja's name
#
# - I used the print function to write Apu Apustaja's name
#
# - I used markdown to write headers and bullett points
