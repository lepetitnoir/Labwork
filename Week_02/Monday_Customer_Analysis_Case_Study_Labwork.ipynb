# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox

pd.options.display.max_rows = 100

# %% [markdown]
# ### Activity 1 (Monday)
#
# - Aggregate data into one Data Frame using Pandas. Pay attention that files may have different names for the same column. therefore, make sure that you unify the columns names before concating them.
# - Standardizing header names
# - Deleting and rearranging columns – delete the column customer as it is only a unique identifier for each row of data
# - Working with data types – Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of open complaints ). Hint: remove the percentage from the customer lifetime value and truncate it to an integer value.
# - clean the number of open complaints and extract the middle number which is changing between records. pay attention that the number of open complaints is a categorical feature.
# - Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns
# - Removing duplicates

# %%
file1 = pd.read_csv("data_CA/file1.csv")

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2 = pd.read_csv("data_CA/file2.csv")

# %%
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file3 = pd.read_csv("data_CA/file3.csv")

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
def lower_case_column_names(file1):
    file1.columns=[i.lower() for i in file1.columns]
    return file1

# %%
lower_case_column_names(file1)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file1.rename(columns={'st':'state'}, inplace = True )

# %%
def lower_case_column_names(file2):
    file2.columns=[i.lower() for i in file2.columns]
    return file2

# %%
lower_case_column_names(file2)
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
file2.rename(columns={'st':'state'}, inplace=True )

# %%
def lower_case_column_names(file3):
    file3.columns=[i.lower() for i in file3.columns]
    return file3

# %%
lower_case_column_names(file3)
# Out:
#      customer       state  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %%
def concatenate_data():
    return pd.concat([file1,file2,file3], axis = 0)

# %%
CA_df = concatenate_data()

# %%
CA_df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
CA_df.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
CA_df = CA_df[['state', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]

# %%
# "income" = yearly income total ("0" can mean no income OR no value), "monthly premium" = insurance price per month, "number of open complaints"  = correct number is in the middle, "total claim amount" = maximum amount of customer's claim per year

CA_df
# Out:
#            state gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
CA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    9130 non-null   object
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  9137 non-null   object
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 1.0+ MB

# %%
CA_df.describe()
# Out:
#              income  monthly premium auto  total claim amount
# count   9137.000000           9137.000000         9137.000000
# mean   37828.820291            110.391266          430.527140
# std    30358.716159            581.376032          289.582968
# min        0.000000             61.000000            0.099007
# 25%        0.000000             68.000000          266.996814
# 50%    34244.000000             83.000000          377.561463
# 75%    62447.000000            109.000000          546.420009
# max    99981.000000          35354.000000         2893.239678

# %%
CA_df['customer lifetime value'] = CA_df['customer lifetime value'].str.rstrip("%")
# Out:
# /var/folders/z7/h39z8zd55hb3q_stjqd0sqgm0000gn/T/ipykernel_81394/579918767.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CA_df['customer lifetime value'] = CA_df['customer lifetime value'].str.rstrip("%")

# %%
CA_df['customer lifetime value'] = pd.to_numeric(CA_df['customer lifetime value'], errors = 'coerce')
# Out:
# /var/folders/z7/h39z8zd55hb3q_stjqd0sqgm0000gn/T/ipykernel_81394/3332590509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CA_df['customer lifetime value'] = pd.to_numeric(CA_df['customer lifetime value'], errors = 'coerce')

# %%
CA_df['customer lifetime value'].unique
# Out:
# <bound method Series.unique of 0              NaN
# 1        697953.59
# 2       1288743.17
# 3        764586.18
# 4        536307.65
#            ...
# 7065           NaN
# 7066           NaN
# 7067           NaN
# 7068           NaN
# 7069           NaN
# Name: customer lifetime value, Length: 12074, dtype: float64>

# %%
CA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    2060 non-null   float64
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  9137 non-null   object
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(4), object(6)
# memory usage: 1.0+ MB

# %%
CA_df.describe()
# Out:
#        customer lifetime value        income  monthly premium auto  \
# count             2.060000e+03   9137.000000           9137.000000
# mean              7.799463e+05  37828.820291            110.391266
# std               6.329809e+05  30358.716159            581.376032
# min               2.004351e+05      0.000000             61.000000
# 25%               3.978076e+05      0.000000             68.000000
# 50%               5.720275e+05  34244.000000             83.000000
# 75%               8.819019e+05  62447.000000            109.000000
# max               5.816655e+06  99981.000000          35354.000000
#
#        total claim amount
# count         9137.000000
# mean           430.527140
# std            289.582968
# min              0.099007
# 25%            266.996814
# 50%            377.561463
# 75%            546.420009
# max           2893.239678

# %%
CA_df['gender'].unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
list(CA_df['gender'].unique())
# Out:
# [nan, 'F', 'M', 'Femal', 'Male', 'female']

# %%
type(list(CA_df['gender'].unique())[3])
# Out:
# str

# %%
type(list(CA_df['gender'])[0])
# Out:
# float

# %%
len(CA_df[CA_df['gender'].isna()==True])
# Out:
# 3059

# %%
list_gender = []

for gender in list(CA_df['gender']):
    if type(gender) == float:
        list_gender.append(gender)
    elif gender.startswith('f'):
        list_gender.append('Female')
    elif gender.startswith('F'):
        list_gender.append('Female')
    elif gender.startswith('m'):
        list_gender.append('Male')
    elif gender.startswith('M'):
        list_gender.append('Male')

# %%
CA_df['gender'] = list_gender
# Out:
# /var/folders/z7/h39z8zd55hb3q_stjqd0sqgm0000gn/T/ipykernel_81394/4108590549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CA_df['gender'] = list_gender

# %%
CA_df['gender']
# Out:
# 0          NaN
# 1       Female
# 2       Female
# 3         Male
# 4         Male
#          ...
# 7065      Male
# 7066    Female
# 7067      Male
# 7068      Male
# 7069      Male
# Name: gender, Length: 12074, dtype: object

# %%
CA_df
# Out:
#            state  gender             education  customer lifetime value  \
# 0     Washington     NaN                Master                      NaN
# 1        Arizona  Female              Bachelor                697953.59
# 2         Nevada  Female              Bachelor               1288743.17
# 3     California    Male              Bachelor                764586.18
# 4     Washington    Male  High School or Below                536307.65
# ...          ...     ...                   ...                      ...
# 7065  California    Male              Bachelor                      NaN
# 7066  California  Female               College                      NaN
# 7067  California    Male              Bachelor                      NaN
# 7068  California    Male               College                      NaN
# 7069  California    Male               College                      NaN
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
# divide by 100 because original series was in percentage points

divided_by_100 = []

for divide in list(CA_df['customer lifetime value']):
    divide = divide/100
    divided_by_100.append(divide)

# %%
CA_df['customer lifetime value'] = divided_by_100
# Out:
# /var/folders/z7/h39z8zd55hb3q_stjqd0sqgm0000gn/T/ipykernel_81394/3089690388.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CA_df['customer lifetime value'] = divided_by_100

# %%
CA_df
# Out:
#            state  gender             education  customer lifetime value  \
# 0     Washington     NaN                Master                      NaN
# 1        Arizona  Female              Bachelor                6979.5359
# 2         Nevada  Female              Bachelor               12887.4317
# 3     California    Male              Bachelor                7645.8618
# 4     Washington    Male  High School or Below                5363.0765
# ...          ...     ...                   ...                      ...
# 7065  California    Male              Bachelor                      NaN
# 7066  California  Female               College                      NaN
# 7067  California    Male              Bachelor                      NaN
# 7068  California    Male               College                      NaN
# 7069  California    Male               College                      NaN
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
CA_df['state'].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
# replacing value by replace-function

CA_df['state'] = CA_df['state'].replace(['WA'],'Washington')
CA_df['state'] = CA_df['state'].replace(['AZ'],'Arizona')
CA_df['state'] = CA_df['state'].replace(['Cali'],'California')
# Out:
# /var/folders/z7/h39z8zd55hb3q_stjqd0sqgm0000gn/T/ipykernel_81394/2027262115.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CA_df['state'] = CA_df['state'].replace(['WA'],'Washington')
# /var/folders/z7/h39z8zd55hb3q_stjqd0sqgm0000gn/T/ipykernel_81394/2027262115.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CA_df['state'] = CA_df['state'].replace(['AZ'],'Arizona')
# /var/folders/z7/h39z8zd55hb3q_stjqd0sqgm0000gn/T/ipykernel_81394/2027262115.py:5: SettingWithCopyWarning:
# ...

# %%
CA_df['education'].unique()
# Out:
# array(['Master', 'Bachelor', 'High School or Below', 'College',
#        'Bachelors', 'Doctor', nan], dtype=object)

# %%
CA_df['education'].value_counts()
# Out:
# Bachelor                2719
# College                 2682
# High School or Below    2616
# Master                   752
# Doctor                   344
# Bachelors                 24
# Name: education, dtype: int64

# %%
CA_df['education'] = CA_df['education'].replace('Bachelors','Bachelor')
# Out:
# /var/folders/z7/h39z8zd55hb3q_stjqd0sqgm0000gn/T/ipykernel_81394/514620404.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CA_df['education'] = CA_df['education'].replace('Bachelors','Bachelor')

# %%
CA_df['education'] = CA_df['education'].replace('College','Bachelor')
# Out:
# /var/folders/z7/h39z8zd55hb3q_stjqd0sqgm0000gn/T/ipykernel_81394/3801875929.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CA_df['education'] = CA_df['education'].replace('College','Bachelor')

# %%
CA_df['education'].unique()
# Out:
# array(['Master', 'Bachelor', 'High School or Below', 'Doctor', nan],
#       dtype=object)

# %%
CA_df['policy type'].unique()
# Out:
# array(['Personal Auto', 'Corporate Auto', 'Special Auto', nan],
#       dtype=object)

# %%
CA_df['vehicle class'].unique()
# Out:
# array(['Four-Door Car', 'Two-Door Car', 'SUV', 'Luxury SUV', 'Sports Car',
#        'Luxury Car', nan], dtype=object)

# %%
CA_df['number of open complaints'].unique()
# Out:
# array(['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00', nan, 0,
#        2, 3, 1, 5, 4], dtype=object)

# %%
set(list(CA_df['number of open complaints']))
# Out:
# {0,
#  1,
#  '1/0/00',
#  '1/1/00',
#  '1/2/00',
#  '1/3/00',
#  '1/4/00',
#  '1/5/00',
#  2,
#  3,
#  4,
#  5,
#  nan}

# %%
# NaN is type float

list_nr_of_open_complaints = []

for complaint in list(CA_df['number of open complaints']):
    if type(complaint) == str:
        list_nr_of_open_complaints.append(int(complaint[2]))
    elif type(complaint) == float:
        list_nr_of_open_complaints.append(complaint)
    elif type(complaint) == int:
        list_nr_of_open_complaints.append(complaint)

# %%
set(list_nr_of_open_complaints)
# Out:
# {0, 1, 2, 3, 4, 5, nan}

# %%
CA_df['number of open complaints'] = list_nr_of_open_complaints
# Out:
# /var/folders/z7/h39z8zd55hb3q_stjqd0sqgm0000gn/T/ipykernel_81394/3269047954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CA_df['number of open complaints'] = list_nr_of_open_complaints

# %%
CA_df['number of open complaints'].unique()
# Out:
# array([ 0.,  2.,  1.,  3.,  5.,  4., nan])

# %%
CA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    2060 non-null   float64
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  9137 non-null   float64
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(5), object(5)
# memory usage: 1.0+ MB

# %%
CA_df
# Out:
#            state  gender             education  customer lifetime value  \
# 0     Washington     NaN                Master                      NaN
# 1        Arizona  Female              Bachelor                6979.5359
# 2         Nevada  Female              Bachelor               12887.4317
# 3     California    Male              Bachelor                7645.8618
# 4     Washington    Male  High School or Below                5363.0765
# ...          ...     ...                   ...                      ...
# 7065  California    Male              Bachelor                      NaN
# 7066  California  Female              Bachelor                      NaN
# 7067  California    Male              Bachelor                      NaN
# 7068  California    Male              Bachelor                      NaN
# 7069  California    Male              Bachelor                      NaN
#
#        income  monthly premium auto  number of open complaints  \
# ...

# %%
CA_df.drop_duplicates()
# Out:
#            state  gender             education  customer lifetime value  \
# 0     Washington     NaN                Master                      NaN
# 1        Arizona  Female              Bachelor                6979.5359
# 2         Nevada  Female              Bachelor               12887.4317
# 3     California    Male              Bachelor                7645.8618
# 4     Washington    Male  High School or Below                5363.0765
# ...          ...     ...                   ...                      ...
# 7065  California    Male              Bachelor                      NaN
# 7066  California  Female              Bachelor                      NaN
# 7067  California    Male              Bachelor                      NaN
# 7068  California    Male              Bachelor                      NaN
# 7069  California    Male              Bachelor                      NaN
#
#        income  monthly premium auto  number of open complaints  \
# ...

# %%
CA_df.to_csv("CA_df.csv",index = False)
