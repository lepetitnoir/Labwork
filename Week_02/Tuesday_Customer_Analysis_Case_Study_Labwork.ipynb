# %% [markdown]
# ### Activity 2 (Tuesday)
# - Replacing null values – Replace missing values with means of the column (for numerical columns). Pay attention that the Income feature for instance has 0s which is equivalent to null values. (We assume here that there is no such income with 0 as it refers to missing values)
# Hint: numpy.nan is considered of float64 data type.
# - Bucketing the data - Write a function to replace column "State" to different zones. California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central
# - (Optional) Standardizing the data – Use string functions to standardize the text data (lower case)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox

pd.options.display.max_rows = 100

# %%
CA_df = pd.read_csv("CA_df.csv")

# %%
CA_df
# Out:
#             state  gender             education  customer lifetime value  \
# 0      Washington     NaN                Master                      NaN
# 1         Arizona  Female              Bachelor                6979.5359
# 2          Nevada  Female              Bachelor               12887.4317
# 3      California    Male              Bachelor                7645.8618
# 4      Washington    Male  High School or Below                5363.0765
# ...           ...     ...                   ...                      ...
# 12069  California    Male              Bachelor                      NaN
# 12070  California  Female               College                      NaN
# 12071  California    Male              Bachelor                      NaN
# 12072  California    Male               College                      NaN
# 12073  California    Male               College                      NaN
#
#         income  monthly premium auto  number of open complaints  \
# ...

# %%
CA_df['number of open complaints'] = str(CA_df['number of open complaints'])

# %%
CA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    2060 non-null   float64
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  12074 non-null  object
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(4), object(6)
# memory usage: 943.4+ KB

# %%
CA_df['customer lifetime value'] = CA_df['customer lifetime value'].fillna(value = CA_df['customer lifetime value'].mean())
CA_df['monthly premium auto'] = CA_df['monthly premium auto'].fillna(value = CA_df['monthly premium auto'].mean())
CA_df['total claim amount'] = CA_df['total claim amount'].fillna(value = CA_df['total claim amount'].mean())

# %%
income_list = []

for income in list(CA_df['income']):
    if income != (0.0):
        income_list.append(income)
    elif income == (0.0):
        income_list.append(np.nan)

# %%
CA_df['income'] = income_list

# %%
CA_df['income'].unique
# Out:
# <bound method Series.unique of 0            NaN
# 1            NaN
# 2        48767.0
# 3            NaN
# 4        36357.0
#           ...
# 12069    71941.0
# 12070    21604.0
# 12071        NaN
# 12072    21941.0
# 12073        NaN
# Name: income, Length: 12074, dtype: float64>

# %%
CA_df['state'].unique
# Out:
# <bound method Series.unique of 0        Washington
# 1           Arizona
# 2            Nevada
# 3        California
# 4        Washington
#             ...
# 12069    California
# 12070    California
# 12071    California
# 12072    California
# 12073    California
# Name: state, Length: 12074, dtype: object>

# %%
state_to_zone_list = [] 

def state_to_zone():
    for state in list(CA_df['state']):
        if state == 'California':
            state_to_zone_list.append('West Region')
        elif state == 'Oregon':
            state_to_zone_list.append('North West')
        elif state == 'Washington':
            state_to_zone_list.append('East')
        elif state == 'Arizona':
           state_to_zone_list.append('Central')
        elif state == 'Nevada':
           state_to_zone_list.append('Central')
        else:
            state_to_zone_list.append(state)

# %%
state_to_zone()

# %%
CA_df['state'] = state_to_zone_list

# %%
CA_df['state'].unique
# Out:
# <bound method Series.unique of 0               East
# 1            Central
# 2            Central
# 3        West Region
# 4               East
#             ...
# 12069    West Region
# 12070    West Region
# 12071    West Region
# 12072    West Region
# 12073    West Region
# Name: state, Length: 12074, dtype: object>

# %%
CA_df.rename(columns = {'state':'zone'}, inplace = True)

# %%
CA_df
# Out:
#               zone  gender             education  customer lifetime value  \
# 0             East     NaN                Master              7799.463082
# 1          Central  Female              Bachelor              6979.535900
# 2          Central  Female              Bachelor             12887.431700
# 3      West Region    Male              Bachelor              7645.861800
# 4             East    Male  High School or Below              5363.076500
# ...            ...     ...                   ...                      ...
# 12069  West Region    Male              Bachelor              7799.463082
# 12070  West Region  Female               College              7799.463082
# 12071  West Region    Male              Bachelor              7799.463082
# 12072  West Region    Male               College              7799.463082
# 12073  West Region    Male               College              7799.463082
#
#         income  monthly premium auto  \
# 0          NaN                1000.0
# ...

# %%
def lower_case_row_names(CA_df):
    CA_df.rows=[i.lower() for i in CA_df.rows]
    return CA_df

# %%
lower_case_row_names(CA_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [102], in <cell line: 1>()
# ----> 1 lower_case_row_names(CA_df)
#
# Input In [101], in lower_case_row_names(CA_df)
#       1 def lower_case_row_names(CA_df):
# ----> 2     CA_df.rows=[i.lower() for i in CA_df.rows]
#       3     return CA_df
#
# File /opt/anaconda3/envs/DA/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
list(CA_df.columns)
# Out:
# ['zone',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'total claim amount']

# %%
CA_df['zone'] = CA_df['zone'].str.lower()

# %%
CA_df['gender'] = CA_df['gender'].str.lower()

# %%
CA_df['education'] = CA_df['education'].str.lower()

# %%
CA_df['policy type'] = CA_df['policy type'].str.lower()

# %%
CA_df['vehicle class'] = CA_df['vehicle class'].str.lower()

# %%
CA_df
# Out:
#               zone  gender             education  customer lifetime value  \
# 0             east     NaN                master              7799.463082
# 1          central  female              bachelor              6979.535900
# 2          central  female              bachelor             12887.431700
# 3      west region    male              bachelor              7645.861800
# 4             east    male  high school or below              5363.076500
# ...            ...     ...                   ...                      ...
# 12069  west region    male              bachelor              7799.463082
# 12070  west region  female               college              7799.463082
# 12071  west region    male              bachelor              7799.463082
# 12072  west region    male               college              7799.463082
# 12073  west region    male               college              7799.463082
#
#         income  monthly premium auto  \
# 0          NaN                1000.0
# ...
